# %% [markdown]
# <a href="https://colab.research.google.com/github/AlonsoLoreto/Actividad-6-Regresi-n-No-Lineal-/blob/main/Actividad6_RegresionNoLineal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Modelo 1: "score_buro"

# %%
# @title
Vars_Indeps1= df[['semana_actual']]
Var_Deps1= df['score_buro']

# %%
# @title
xs1= Vars_Indeps1
ys1= Var_Deps1

# %%
# @title
def  funcs1 (x, a, b, c):
     return (a*x**10 + b)/ c*x

# %%
# @title
parametros, covs= curve_fit(funcs1, df['semana_actual'], df['score_buro'])

# %%
# @title
parametros
# Out:
# array([-1.13428383e-14,  6.37462082e+03,  8.01064959e+02])

# %%
# @title
parametros, _ = curve_fit(funcs1, df['semana_actual'], df['score_buro'])
a, b, c = parametros[ 0 ], parametros[ 1 ], parametros[ 2 ]
yfits1 = (a*x**10 + b)/ c*x

# %%
# @title
yfits1
# Out:
#        limite_credito
# 0       -6.913915e+23
# 1       -5.137097e+24
# 2        0.000000e+00
# 3       -2.799835e+25
# 4       -2.799835e+25
# ...               ...
# 22730   -1.415970e+27
# 22731   -6.913915e+23
# 22732   -3.932636e+23
# 22733   -2.799835e+25
# 22734   -3.932636e+23
#
# [22735 rows x 1 columns]

# %%
# @title
plt.plot(xs1, ys1, 'bo', label="y-original")
plt.plot(xs1, yfits1, label="(a*x**2 + b)/ c*x")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
# @title
R2s1 = r2_score(ys1, yfits1)
R2s1
# Out:
# -6.734000090070038e+48

# %%
# @title
corrs1= np.sqrt(abs(R2s1))
corrs1
# Out:
# 2.5949952003944127e+24

# %% [markdown]
# ## Modelo 2: "score_buro"

# %%
Vars_Indeps2= df[['status']]
Var_Deps2= df['score_buro']

# %%
xs2= Vars_Indeps2
ys2= Var_Deps2

# %%
def  funcs2 (x, a, b, c):
     return a*x**2 + b*x + c

# %%
parametros, covs= curve_fit(funcs2, df['status'], df['score_buro'])

# %%
parametros
# Out:
# array([ 1320.45018916, -4114.32752123,  3122.70414936])

# %%
parametros, _ = curve_fit(funcr2, df['status'], df['score_buro'])
a, b, c = parametros[ 0 ], parametros[ 1 ], parametros[ 2 ]
yfits2 = a*x**2 + b*x + c

# %%
yfits2
# Out:
#        limite_credito
# 0        3.299069e+10
# 1        4.751152e+10
# 2        3.122704e+03
# 3        6.467326e+10
# 4        6.467326e+10
# ...               ...
# 22730    1.320039e+11
# 22731    3.299069e+10
# 22732    2.977312e+10
# 22733    6.467326e+10
# 22734    2.977312e+10
#
# [22735 rows x 1 columns]

# %%
plt.plot(xs2, ys2, 'bo', label="y-original")
plt.plot(xs2, yfits2, label="a*x**2 + b*x + c")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
R2s2 = r2_score(ys2, yfits2)
R2s2
# Out:
# -5.054485123072569e+16

# %%
corrs2= np.sqrt(abs(R2s2))
corrs2
# Out:
# 224821821.07332394

# %% [markdown]
# ##Modelo 3: "score_buro"

# %%
Vars_Indeps3= df[['pagos_realizados']]
Var_Deps3= df['score_buro']

# %%
xs3= Vars_Indeps3
ys3= Var_Deps3

# %%
def  funcs3 (x, a, b, c):
     return 1/a*x

# %%
parametros, covs= curve_fit(funcs3, df['pagos_realizados'], df['score_buro'])
# Out:
# /usr/local/lib/python3.10/dist-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
parametros
# Out:
# array([0.07846939, 1.        , 1.        ])

# %%
parametros, _ = curve_fit(funcs3, df['pagos_realizados'], df['score_buro'])
a, b, c = parametros[ 0 ], parametros[ 1 ], parametros[ 2 ]
yfits3 = 1/a*x

# %%
yfits3
# Out:
#        limite_credito
# 0        63719.109946
# 1        76462.931935
# 2            0.000000
# 3        89206.753925
# 4        89206.753925
# ...               ...
# 22730   127438.219892
# 22731    63719.109946
# 22732    60533.154449
# 22733    89206.753925
# 22734    60533.154449
#
# [22735 rows x 1 columns]

# %%
plt.plot(xs3, ys3, 'bo', label="y-original")
plt.plot(xs3, yfits3, label="1/a*x")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
R2s3 = r2_score(ys3, yfits3)
R2s3
# Out:
# -79122.98695867442

# %%
corrs3= np.sqrt(abs(R2s3))
corrs3
# Out:
# 281.2880853478768

# %% [markdown]
# ## Modelo 4: "score_buro"

# %%
Vars_Indeps4= df[['puntos']]
Var_Deps4= df['score_buro']

# %%
xs4= Vars_Indeps4
ys4= Var_Deps4

# %%
def  funcs4 (x, a, b, c):
     return a*x + b*x + c*x

# %%
parametros, covs= curve_fit(funcs4, df['puntos'], df['score_buro'])

# %%
parametros
# Out:
# array([144.83396758, -67.29807126, -67.29807126])

# %%
parametros, _ = curve_fit(funcr4, df['puntos'], df['score_buro'])
a, b, c = parametros[ 0 ], parametros[ 1 ], parametros[ 2 ]
yfits4 = a*x + b*x + c*x

# %%
yfits4
# Out:
#        limite_credito
# 0        51189.125335
# 1        61426.950402
# 2            0.000000
# 3        71664.775469
# 4        71664.775469
# ...               ...
# 22730   102378.250670
# 22731    51189.125335
# 22732    48629.669068
# 22733    71664.775469
# 22734    48629.669068
#
# [22735 rows x 1 columns]

# %%
plt.plot(xs4, ys4, 'bo', label="y-original")
plt.plot(xs4, yfits4, label="a*x + b*x + c*x")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
R2s4 = r2_score(ys4, yfits4)
R2s4
# Out:
# -50983.81943004082

# %%
corrs4= np.sqrt(abs(R2s4))
corrs4
# Out:
# 225.79596858677706

# %% [markdown]
# ## Modelo 5: "score_buro"

# %%
Vars_Indeps5= df[['limite_credito']]
Var_Deps5= df['score_buro']

# %%
xs5= Vars_Indeps5
ys5= Var_Deps5

# %%
def  funcs5 (x, a, b, c):
     return a/b*x**2 + c*x

# %%
parametros, covs= curve_fit(funcs5, df['limite_credito'], df['score_buro'])

# %%
parametros
# Out:
# array([-4.07936807e-03,  3.71214624e+02,  1.22238317e-01])

# %%
parametros, _ = curve_fit(funcr1, df['limite_credito'], df['score_buro'])
a, b, c = parametros[ 0 ], parametros[ 1 ], parametros[ 2 ]
yfits5 = a/b*x**2 + c*x
# Out:
# /usr/local/lib/python3.10/dist-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
yfits5
# Out:
#        limite_credito
# 0       426475.255373
# 1       511770.306447
# 2            0.000000
# 3       597065.357522
# 4       597065.357522
# ...               ...
# 22730   852950.510746
# 22731   426475.255373
# 22732   405151.492604
# 22733   597065.357522
# 22734   405151.492604
#
# [22735 rows x 1 columns]

# %%
plt.plot(xs5, ys5, 'bo', label="y-original")
plt.plot(xs5, yfits5, label="a/b*x**2 + c*x")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
R2s5 = r2_score(ys5, yfits5)
R2s5
# Out:
# -3563959.7120368658

# %%
corrs5= np.sqrt(abs(R2s5))
corrs5
# Out:
# 1887.8452563801054

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.special as special
from scipy.optimize import curve_fit
import seaborn as sns
from sklearn.metrics import r2_score

# %%
df= pd.read_csv('cuentas_credicel.csv', encoding = 'latin')
df.head(5)
# Out:
# <ipython-input-511-eb6c34c8d911>:1: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv('cuentas_credicel.csv', encoding = 'latin')
#    folio       tag  folio_solicitud           fecha     marca  \
# 0      3  HDNAWQ3A               30  12/11/21 19:00       ZTE
# 1      4  M418YNR4               33  12/11/21 19:15  MOTOROLA
# 2      5  SZ7V3NZT               37  13/11/21 14:13       ZTE
# 3      6  9I08UIQZ               38  13/11/21 15:45       ZTE
# 4      7  JMF4LKYU               44  13/11/21 16:10  MOTOROLA
#
#                          modelo plazo  precio  enganche  descuento  ...  \
# 0            Blade A3 2020 RO B   26S  1949.0     780.0        0.0  ...
# 1  LTE XT2097-12 E7I POWER Azul   13S  2999.0    1050.0        0.0  ...
# 2            BLADE A3 2020 Gris   13S  1959.0     490.0        0.0  ...
# 3            BLADE A3 2020 Gris   13S  1959.0     490.0        0.0  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22735 entries, 0 to 22734
# Data columns (total 39 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   folio               22735 non-null  int64
#  1   tag                 22735 non-null  object
#  2   folio_solicitud     22735 non-null  int64
#  3   fecha               22735 non-null  object
#  4   marca               22735 non-null  object
#  5   modelo              22735 non-null  object
#  6   plazo               22735 non-null  object
#  7   precio              22735 non-null  float64
#  8   enganche            22735 non-null  float64
#  9   descuento           22735 non-null  float64
#  10  semana              22735 non-null  int64
#  11  monto_financiado    22735 non-null  float64
#  12  costo_total         22735 non-null  int64
#  13  monto_accesorios    22735 non-null  float64
#  14  agente_venta        22735 non-null  object
# ...

# %%
df['edad_cliente'].fillna('mode', inplace=True)
df['edo_cliente'].fillna('mode', inplace=True)
df['cd_venta'].fillna('mode', inplace=True)
df['edo_venta'].fillna('mode', inplace=True)
df['empresa'].fillna('mode', inplace=True)

# %%
df = df.drop('curp', axis=1)
df = df.drop('fecha_ultimo_pago', axis=1)
df = df.drop('fecha_pago_proximo', axis=1)
df = df.drop('status_cuenta', axis=1)
df = df.drop('cp_cliente', axis=1)
df = df.drop('razones_buro', axis=1)
df = df.drop('reautorizacion', axis=1)
df = df.drop('fraude', axis=1)

# %%
df['limite_credito'] = df['limite_credito'].replace('SD', 0)
df['limite_credito'] = df['limite_credito'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22735 entries, 0 to 22734
# Data columns (total 31 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   folio             22735 non-null  int64
#  1   tag               22735 non-null  object
#  2   folio_solicitud   22735 non-null  int64
#  3   fecha             22735 non-null  object
#  4   marca             22735 non-null  object
#  5   modelo            22735 non-null  object
#  6   plazo             22735 non-null  object
#  7   precio            22735 non-null  float64
#  8   enganche          22735 non-null  float64
#  9   descuento         22735 non-null  float64
#  10  semana            22735 non-null  int64
#  11  monto_financiado  22735 non-null  float64
#  12  costo_total       22735 non-null  int64
#  13  monto_accesorios  22735 non-null  float64
#  14  agente_venta      22735 non-null  object
#  15  dis_venta         22735 non-null  object
# ...

# %%
df.corr()
# Out:
# <ipython-input-517-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                      folio  folio_solicitud    precio  enganche  descuento  \
# folio             1.000000         0.971332  0.098971  0.124622   0.130377
# folio_solicitud   0.971332         1.000000  0.099934  0.121863   0.127074
# precio            0.098971         0.099934  1.000000  0.678519   0.009883
# enganche          0.124622         0.121863  0.678519  1.000000  -0.025689
# descuento         0.130377         0.127074  0.009883 -0.025689   1.000000
# semana            0.094659         0.097633  0.672673  0.339912  -0.026317
# monto_financiado  0.075446         0.077342  0.947080  0.408276   0.024136
# costo_total       0.027103         0.029438  0.872403  0.355694   0.036940
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22735 entries, 0 to 22734
# Data columns (total 31 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   folio             22735 non-null  int64
#  1   tag               22735 non-null  object
#  2   folio_solicitud   22735 non-null  int64
#  3   fecha             22735 non-null  object
#  4   marca             22735 non-null  object
#  5   modelo            22735 non-null  object
#  6   plazo             22735 non-null  object
#  7   precio            22735 non-null  float64
#  8   enganche          22735 non-null  float64
#  9   descuento         22735 non-null  float64
#  10  semana            22735 non-null  int64
#  11  monto_financiado  22735 non-null  float64
#  12  costo_total       22735 non-null  int64
#  13  monto_accesorios  22735 non-null  float64
#  14  agente_venta      22735 non-null  object
#  15  dis_venta         22735 non-null  object
# ...

# %%
df['empresa'].value_counts()
# Out:
# microtec             9310
# servicel             7348
# comunicatec          1020
# procredito            697
# phonepay              456
# texpress              396
# centrocel             395
# apartacel             324
# yaavs                 258
# aespinosa             221
# leket                 186
# compercel             174
# linetelc              172
# arcelular             171
# telesystems           156
# crglobal              153
# grupoph               136
# redworld              126
# pixelulares           112
# emnagar                81
# phuny                  80
# drmedia                73
# quality                71
# tucelya                65
# maifon                 60
# todocell               52
# mistraltechnology      48
# financel               46
# fixmobile              43
# alessan                39
# satelitel              36
# ahorrocelsonora        35
# signumaxis             35
# ccelular               32
# phoneone               24
# ...

# %%
fig = plt.figure(figsize = (20, 10))
df.plot(kind="box", vert = False)
plt.title("Boxplot")
plt.show()

# %%
df = df.drop(df.columns[[1, 2, 3, 4, 5, 6, 14, 15, 18, 28, 29, 30]], axis=1)

# %%
df.corr()
# Out:
# <ipython-input-522-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                      folio    precio  enganche  descuento    semana  \
# folio             1.000000  0.098971  0.124622   0.130377  0.094659
# precio            0.098971  1.000000  0.678519   0.009883  0.672673
# enganche          0.124622  0.678519  1.000000  -0.025689  0.339912
# descuento         0.130377  0.009883 -0.025689   1.000000 -0.026317
# semana            0.094659  0.672673  0.339912  -0.026317  1.000000
# monto_financiado  0.075446  0.947080  0.408276   0.024136  0.688111
# costo_total       0.027103  0.872403  0.355694   0.036940  0.411911
# monto_accesorios  0.081637  0.019097  0.031409  -0.006212  0.028635
# status           -0.381641 -0.096183 -0.032450  -0.076093  0.143145
# ...

# %%
y=df
Limite_Superior= y.mean() + 3* y.std()
Limite_Inferior= y.mean() - 3 * y.std()
print("Limite Superior Permitido", Limite_Superior)
print("Limite Inferior Permitido", Limite_Inferior)
# Out:
# <ipython-input-523-3b2f7da30154>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Superior= y.mean() + 3* y.std()
# <ipython-input-523-3b2f7da30154>:2: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Superior= y.mean() + 3* y.std()
# Limite Superior Permitido folio               31323.107698
# precio               8081.558082
# enganche             2356.496845
# descuento             478.215020
# semana                541.287392
# monto_financiado     6366.317810
# costo_total         12857.588246
# ...

# %%
df[['folio','precio','enganche','descuento','semana', 'monto_financiado', 'costo_total','monto_accesorios', 'status','pagos_realizados','puntos','riesgo','score_buro','porc_eng','limite_credito','semana_actual']]= df[['folio','precio','enganche','descuento','semana', 'monto_financiado', 'costo_total','monto_accesorios', 'status','pagos_realizados','puntos','riesgo','score_buro','porc_eng','limite_credito','semana_actual']][(y<=Limite_Superior)&(y>=Limite_Inferior)]
df.head()
# Out:
# <ipython-input-524-767f07089dbf>:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   df[['folio','precio','enganche','descuento','semana', 'monto_financiado', 'costo_total','monto_accesorios', 'status','pagos_realizados','puntos','riesgo','score_buro','porc_eng','limite_credito','semana_actual']]= df[['folio','precio','enganche','descuento','semana', 'monto_financiado', 'costo_total','monto_accesorios', 'status','pagos_realizados','puntos','riesgo','score_buro','porc_eng','limite_credito','semana_actual']][(y<=Limite_Superior)&(y>=Limite_Inferior)]
#    folio  precio  enganche  descuento  semana  monto_financiado  costo_total  \
# 0      3  1949.0     780.0        0.0    81.0            1169.0       2106.0
# 1      4  2999.0    1050.0        0.0   225.0            1949.0       2925.0
# ...

# %%
df = df.fillna(df.mean())
# Out:
# <ipython-input-525-04e87d67d337>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df = df.fillna(df.mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22735 entries, 0 to 22734
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   folio             22735 non-null  int64
#  1   precio            22735 non-null  float64
#  2   enganche          22735 non-null  float64
#  3   descuento         22735 non-null  float64
#  4   semana            22735 non-null  float64
#  5   monto_financiado  22735 non-null  float64
#  6   costo_total       22735 non-null  float64
#  7   monto_accesorios  22735 non-null  float64
#  8   status            22735 non-null  float64
#  9   empresa           22735 non-null  object
#  10  pagos_realizados  22735 non-null  float64
#  11  puntos            22735 non-null  float64
#  12  riesgo            22735 non-null  float64
#  13  score_buro        22735 non-null  int64
#  14  porc_eng          22735 non-null  float64
#  15  limite_credito    22735 non-null  float64
# ...

# %%
riesgo = df.corr()['riesgo']
sb = df.corr()['score_buro']
pe = df.corr()['porc_eng']
lm = df.corr()['limite_credito']
# Out:
# <ipython-input-527-4ad34299499c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   riesgo = df.corr()['riesgo']
# <ipython-input-527-4ad34299499c>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sb = df.corr()['score_buro']
# <ipython-input-527-4ad34299499c>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   pe = df.corr()['porc_eng']
# ...

# %%
dfcorr = pd.DataFrame({'riesgo': riesgo, 'score_buro': sb, 'porc_eng': pe, 'limite_credito': lm})
dfcorr
# Out:
#                     riesgo  score_buro  porc_eng  limite_credito
# folio             0.360561    0.548206  0.085404       -0.389241
# precio           -0.042130    0.077478 -0.037844        0.071461
# enganche          0.300961    0.069649  0.550999       -0.363671
# descuento         0.044846    0.106816 -0.058825       -0.099431
# semana           -0.071683    0.060465 -0.115539        0.097150
# monto_financiado -0.173171    0.073016 -0.253559        0.215092
# costo_total      -0.170578    0.077757 -0.256817        0.216293
# monto_accesorios  0.059312    0.061046  0.000026       -0.054171
# status           -0.162938   -0.230339 -0.012592        0.155638
# pagos_realizados -0.240762   -0.202124 -0.162115        0.248297
# puntos           -0.454681   -0.223928 -0.432249        0.517591
# riesgo            1.000000   -0.059011  0.539671       -0.736225
# score_buro       -0.059011    1.000000  0.018613       -0.153349
# ...

# %% [markdown]
# ## **VARIABLE RIESGO**

# %% [markdown]
# ##Modelo 1: "riesgo"

# %%
# @title
Vars_Indepr1= df[['limite_credito']]
Var_Depr1= df['riesgo']

# %%
# @title
xr1= Vars_Indepr1
yr1= Var_Depr1

# %%
# @title
def  funcr1 (x, a, b, c):
     return (a*x**10 + b)/ c*x

# %%
# @title
parametros, covs= curve_fit(funcr1, df['limite_credito'], df['riesgo'])
# Out:
# /usr/local/lib/python3.10/dist-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
# @title
parametros
# Out:
# array([5.48657915e-17, 1.00000000e+00, 8.52950511e+01])

# %%
# @title
parametros, _ = curve_fit(funcr1, df['limite_credito'], df['riesgo'])
a, b, c = parametros[ 0 ], parametros[ 1 ], parametros[ 2 ]
yfitr1 = (a*x**10 + b)/ c*x

# %%
# @title
yfitr1
# Out:
#        limite_credito
# 0        3.140855e+22
# 1        2.333681e+23
# 2        0.000000e+00
# 3        1.271910e+24
# 4        1.271910e+24
# ...               ...
# 22730    6.432471e+25
# 22731    3.140855e+22
# 22732    1.786519e+22
# 22733    1.271910e+24
# 22734    1.786519e+22
#
# [22735 rows x 1 columns]

# %%
# @title
plt.plot(xr1, yr1, 'bo', label="y-original")
plt.plot(xr1, yfitr1, label="(a*x**2 + b)/ c*x")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
# @title
R2r1 = r2_score(yr1, yfitr1)
R2r1
# Out:
# -3.703393826969856e+48

# %%
# @title
corrr1= np.sqrt(abs(R2r1))
corrr1
# Out:
# 1.924420387277649e+24

# %% [markdown]
# ## Modelo 2: "riesgo"

# %%
Vars_Indepr2= df[['porc_eng']]
Var_Depr2= df['riesgo']

# %%
xr2= Vars_Indepr2
yr2= Var_Depr2

# %%
def  funcr2 (x, a, b, c):
     return a*x**2 + b*x + c

# %%
parametros, covs= curve_fit(funcr2, df['porc_eng'], df['riesgo'])

# %%
parametros
# Out:
# array([-2.04072559e-02,  2.54526681e+00, -4.14388513e+01])

# %%
parametros, _ = curve_fit(funcr2, df['porc_eng'], df['riesgo'])
a, b, c = parametros[ 0 ], parametros[ 1 ], parametros[ 2 ]
yfitr2 = a*x**2 + b*x + c

# %%
yfitr2
# Out:
#        limite_credito
# 0       -4.974965e+05
# 1       -7.194310e+05
# 2       -4.143885e+01
# 3       -9.821801e+05
# 4       -9.821801e+05
# ...               ...
# 22730   -2.015314e+06
# 22731   -4.974965e+05
# 22732   -4.483901e+05
# 22733   -9.821801e+05
# 22734   -4.483901e+05
#
# [22735 rows x 1 columns]

# %%
plt.plot(xr2, yr2, 'bo', label="y-original")
plt.plot(xr2, yfitr2, label="a*x**2 + b*x + c")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
R2r2 = r2_score(yr2, yfitr2)
R2r2
# Out:
# -3120458430.5079007

# %%
corrr2= np.sqrt(abs(R2r2))
corrr2
# Out:
# 55861.06363566577

# %% [markdown]
# ##Modelo 3: "riesgo"

# %%
Vars_Indepr3= df[['enganche']]
Var_Depr3= df['riesgo']

# %%
xr3= Vars_Indepr3
yr3= Var_Depr3

# %%
def  funcr3 (x, a, b, c):
     return 1/a*x

# %%
parametros, covs= curve_fit(funcr3, df['enganche'], df['riesgo'])
# Out:
# /usr/local/lib/python3.10/dist-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
parametros
# Out:
# array([141.84680819,   1.        ,   1.        ])

# %%
parametros, _ = curve_fit(funcr3, df['enganche'], df['riesgo'])
a, b, c = parametros[ 0 ], parametros[ 1 ], parametros[ 2 ]
yfitr3 = 1/a*x

# %%
yfitr3
# Out:
#        limite_credito
# 0           35.249295
# 1           42.299154
# 2            0.000000
# 3           49.349013
# 4           49.349013
# ...               ...
# 22730       70.498590
# 22731       35.249295
# 22732       33.486830
# 22733       49.349013
# 22734       33.486830
#
# [22735 rows x 1 columns]

# %%
plt.plot(xr3, yr3, 'bo', label="y-original")
plt.plot(xr3, yfitr3, label="1/a*x")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
R2r3 = r2_score(yr3, yfitr3)
R2r3
# Out:
# -6.411522996232392

# %%
corrr3= np.sqrt(abs(R2r3))
corrr3
# Out:
# 2.5320985360432546

# %% [markdown]
# ## Modelo 4: "riesgo"

# %%
Vars_Indepr4= df[['puntos']]
Var_Depr4= df['riesgo']

# %%
xr4= Vars_Indepr4
yr4= Var_Depr4

# %%
def  funcr4 (x, a, b, c):
     return a*x + b*x + c*x

# %%
parametros, covs= curve_fit(funcr4, df['puntos'], df['riesgo'])

# %%
parametros
# Out:
# array([141.40530563, -70.72672873, -70.72672873])

# %%
parametros, _ = curve_fit(funcr4, df['puntos'], df['riesgo'])
a, b, c = parametros[ 0 ], parametros[ 1 ], parametros[ 2 ]
yfitr4 = a*x + b*x + c*x

# %%
yfitr4
# Out:
#        limite_credito
# 0         -240.759153
# 1         -288.910984
# 2            0.000000
# 3         -337.062815
# 4         -337.062815
# ...               ...
# 22730     -481.518307
# 22731     -240.759153
# 22732     -228.721196
# 22733     -337.062815
# 22734     -228.721196
#
# [22735 rows x 1 columns]

# %%
plt.plot(xr4, yr4, 'bo', label="y-original")
plt.plot(xr4, yfitr4, label="a*x + b*x + c*x")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
R2r4 = r2_score(yr4, yfitr4)
R2r4
# Out:
# -304.2536583527683

# %%
corrr4= np.sqrt(abs(R2r4))
corrr4
# Out:
# 17.442868409546875

# %% [markdown]
# ## Modelo 5: "riesgo"

# %%
Vars_Indepr5= df[['semana_actual']]
Var_Depr5= df['riesgo']

# %%
xr5= Vars_Indepr5
yr5= Var_Depr5

# %%
def  funcr5 (x, a, b, c):
     return a/b*x**2 + c*x

# %%
parametros, covs= curve_fit(funcr5, df['semana_actual'], df['riesgo'])

# %%
parametros
# Out:
# array([-0.73573959, 52.77255551,  0.56355024])

# %%
parametros, _ = curve_fit(funcr1, df['semana_actual'], df['riesgo'])
a, b, c = parametros[ 0 ], parametros[ 1 ], parametros[ 2 ]
yfitr5 = a/b*x**2 + c*x

# %%
yfitr5
# Out:
#        limite_credito
# 0        9.091121e+09
# 1        1.090935e+10
# 2        0.000000e+00
# 3        1.272757e+10
# 4        1.272757e+10
# ...               ...
# 22730    1.818224e+10
# 22731    9.091121e+09
# 22732    8.636565e+09
# 22733    1.272757e+10
# 22734    8.636565e+09
#
# [22735 rows x 1 columns]

# %%
plt.plot(xr5, yr5, 'bo', label="y-original")
plt.plot(xr5, yfitr5, label="a/b*x**2 + c*x")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
R2r5 = r2_score(yr5, yfitr5)
R2r5
# Out:
# -4.3199331368447936e+17

# %%
corrr5= np.sqrt(abs(R2r5))
corrr5
# Out:
# 657261982.533966

# %% [markdown]
# ## **VARIABLE SCORE_BURO**

# %% [markdown]
# ##Modelo 1: "score_buro"

# %%
# @title
Vars_Indeps1= df[['semana_actual']]
Var_Deps1= df['score_buro']

# %%
# @title
xs1= Vars_Indeps1
ys1= Var_Deps1

# %%
# @title
def  funcs1 (x, a, b, c):
     return (a*x**10 + b)/ c*x

# %%
# @title
parametros, covs= curve_fit(funcs1, df['semana_actual'], df['score_buro'])

# %%
# @title
parametros
# Out:
# array([-1.13428383e-14,  6.37462082e+03,  8.01064959e+02])

# %%
# @title
parametros, _ = curve_fit(funcs1, df['semana_actual'], df['score_buro'])
a, b, c = parametros[ 0 ], parametros[ 1 ], parametros[ 2 ]
yfits1 = (a*x**10 + b)/ c*x

# %%
# @title
yfits1
# Out:
#        limite_credito
# 0       -6.913915e+23
# 1       -5.137097e+24
# 2        0.000000e+00
# 3       -2.799835e+25
# 4       -2.799835e+25
# ...               ...
# 22730   -1.415970e+27
# 22731   -6.913915e+23
# 22732   -3.932636e+23
# 22733   -2.799835e+25
# 22734   -3.932636e+23
#
# [22735 rows x 1 columns]

# %%
# @title
plt.plot(xs1, ys1, 'bo', label="y-original")
plt.plot(xs1, yfits1, label="(a*x**2 + b)/ c*x")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
# @title
R2s1 = r2_score(ys1, yfits1)
R2s1
# Out:
# -6.734000090070038e+48

# %%
# @title
corrs1= np.sqrt(abs(R2s1))
corrs1
# Out:
# 2.5949952003944127e+24

# %% [markdown]
# ## Modelo 2: "score_buro"

# %%
Vars_Indeps2= df[['status']]
Var_Deps2= df['score_buro']

# %%
xs2= Vars_Indeps2
ys2= Var_Deps2

# %%
def  funcs2 (x, a, b, c):
     return a*x**2 + b*x + c

# %%
parametros, covs= curve_fit(funcs2, df['status'], df['score_buro'])

# %%
parametros
# Out:
# array([ 1320.45018916, -4114.32752123,  3122.70414936])

# %%
parametros, _ = curve_fit(funcr2, df['status'], df['score_buro'])
a, b, c = parametros[ 0 ], parametros[ 1 ], parametros[ 2 ]
yfits2 = a*x**2 + b*x + c

# %%
yfits2
# Out:
#        limite_credito
# 0        3.299069e+10
# 1        4.751152e+10
# 2        3.122704e+03
# 3        6.467326e+10
# 4        6.467326e+10
# ...               ...
# 22730    1.320039e+11
# 22731    3.299069e+10
# 22732    2.977312e+10
# 22733    6.467326e+10
# 22734    2.977312e+10
#
# [22735 rows x 1 columns]

# %%
plt.plot(xs2, ys2, 'bo', label="y-original")
plt.plot(xs2, yfits2, label="a*x**2 + b*x + c")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
R2s2 = r2_score(ys2, yfits2)
R2s2
# Out:
# -5.054485123072569e+16

# %%
corrs2= np.sqrt(abs(R2s2))
corrs2
# Out:
# 224821821.07332394

# %% [markdown]
# ##Modelo 3: "score_buro"

# %%
Vars_Indeps3= df[['pagos_realizados']]
Var_Deps3= df['score_buro']

# %%
xs3= Vars_Indeps3
ys3= Var_Deps3

# %%
def  funcs3 (x, a, b, c):
     return 1/a*x

# %%
parametros, covs= curve_fit(funcs3, df['pagos_realizados'], df['score_buro'])
# Out:
# /usr/local/lib/python3.10/dist-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
parametros
# Out:
# array([0.07846939, 1.        , 1.        ])

# %%
parametros, _ = curve_fit(funcs3, df['pagos_realizados'], df['score_buro'])
a, b, c = parametros[ 0 ], parametros[ 1 ], parametros[ 2 ]
yfits3 = 1/a*x

# %%
yfits3
# Out:
#        limite_credito
# 0        63719.109946
# 1        76462.931935
# 2            0.000000
# 3        89206.753925
# 4        89206.753925
# ...               ...
# 22730   127438.219892
# 22731    63719.109946
# 22732    60533.154449
# 22733    89206.753925
# 22734    60533.154449
#
# [22735 rows x 1 columns]

# %%
plt.plot(xs3, ys3, 'bo', label="y-original")
plt.plot(xs3, yfits3, label="1/a*x")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
R2s3 = r2_score(ys3, yfits3)
R2s3
# Out:
# -79122.98695867442

# %%
corrs3= np.sqrt(abs(R2s3))
corrs3
# Out:
# 281.2880853478768

# %% [markdown]
# ## Modelo 4: "score_buro"

# %%
Vars_Indeps4= df[['puntos']]
Var_Deps4= df['score_buro']

# %%
xs4= Vars_Indeps4
ys4= Var_Deps4

# %%
def  funcs4 (x, a, b, c):
     return a*x + b*x + c*x

# %%
parametros, covs= curve_fit(funcs4, df['puntos'], df['score_buro'])

# %%
parametros
# Out:
# array([144.83396758, -67.29807126, -67.29807126])

# %%
parametros, _ = curve_fit(funcr4, df['puntos'], df['score_buro'])
a, b, c = parametros[ 0 ], parametros[ 1 ], parametros[ 2 ]
yfits4 = a*x + b*x + c*x

# %%
yfits4
# Out:
#        limite_credito
# 0        51189.125335
# 1        61426.950402
# 2            0.000000
# 3        71664.775469
# 4        71664.775469
# ...               ...
# 22730   102378.250670
# 22731    51189.125335
# 22732    48629.669068
# 22733    71664.775469
# 22734    48629.669068
#
# [22735 rows x 1 columns]

# %%
plt.plot(xs4, ys4, 'bo', label="y-original")
plt.plot(xs4, yfits4, label="a*x + b*x + c*x")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
R2s4 = r2_score(ys4, yfits4)
R2s4
# Out:
# -50983.81943004082

# %%
corrs4= np.sqrt(abs(R2s4))
corrs4
# Out:
# 225.79596858677706

# %% [markdown]
# ## Modelo 5: "score_buro"

# %%
Vars_Indeps5= df[['limite_credito']]
Var_Deps5= df['score_buro']

# %%
xs5= Vars_Indeps5
ys5= Var_Deps5

# %%
def  funcs5 (x, a, b, c):
     return a/b*x**2 + c*x

# %%
parametros, covs= curve_fit(funcs5, df['limite_credito'], df['score_buro'])

# %%
parametros
# Out:
# array([-4.07936807e-03,  3.71214624e+02,  1.22238317e-01])

# %%
parametros, _ = curve_fit(funcs5, df['limite_credito'], df['score_buro'])
a, b, c = parametros[ 0 ], parametros[ 1 ], parametros[ 2 ]
yfits5 = a/b*x**2 + c*x

# %%
yfits5
# Out:
#        limite_credito
# 0          336.460484
# 1          337.817117
# 2            0.000000
# 3          317.195262
# 4          317.195262
# ...               ...
# 22730      123.458769
# 22731      336.460484
# 22732      332.687187
# 22733      317.195262
# 22734      332.687187
#
# [22735 rows x 1 columns]

# %%
plt.plot(xs5, ys5, 'bo', label="y-original")
plt.plot(xs5, yfits5, label="a/b*x**2 + c*x")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
R2s5 = r2_score(ys5, yfits5)
R2s5
# Out:
# 0.052771454400179274

# %%
corrs5= np.sqrt(abs(R2s5))
corrs5
# Out:
# 0.2297203830751187

# %% [markdown]
# ##Modelo 1: "limite_credito"

# %%
# @title
Vars_Indepl1= df[['semana_actual']]
Var_Depl1= df['limite_credito']

# %%
# @title
xl1= Vars_Indepl1
yl1= Var_Depl1

# %%
# @title
def  funcl1 (x, a, b, c):
     return (a*x**10 + b)/ c*x

# %%
# @title
parametros, covs= curve_fit(funcl1, df['semana_actual'], df['limite_credito'])

# %%
# @title
parametros
# Out:
# array([-5.61904038e-14,  6.33624474e+04,  2.73028050e+02])

# %%
# @title
parametros, _ = curve_fit(funcl1, df['semana_actual'], df['limite_credito'])
a, b, c = parametros[ 0 ], parametros[ 1 ], parametros[ 2 ]
yfitl1 = (a*x**10 + b)/ c*x

# %%
# @title
yfitl1
# Out:
#        limite_credito
# 0       -1.004905e+25
# 1       -7.466527e+25
# 2        0.000000e+00
# 3       -4.069428e+26
# 4       -4.069428e+26
# ...               ...
# 22730   -2.058045e+28
# 22731   -1.004905e+25
# 22732   -5.715900e+24
# 22733   -4.069428e+26
# 22734   -5.715900e+24
#
# [22735 rows x 1 columns]

# %%
# @title
plt.plot(xl1, yl1, 'bo', label="y-original")
plt.plot(xl1, yfitl1, label="(a*x**2 + b)/ c*x")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
# @title
R2l1 = r2_score(yl1, yfitl1)
R2l1
# Out:
# -2.5260434189635116e+49

# %%
# @title
corrl1= np.sqrt(abs(R2l1))
corrl1
# Out:
# 5.025975943996859e+24

# %% [markdown]
# ## Modelo 2: "limite_credito"

# %%
Vars_Indepl2= df[['porc_eng']]
Var_Depl2= df['limite_credito']

# %%
xl2= Vars_Indepl2
yl2= Var_Depl2

# %%
def  funcl2 (x, a, b, c):
     return a*x**2 + b*x + c

# %%
parametros, covs= curve_fit(funcl2, df['porc_eng'], df['limite_credito'])

# %%
parametros
# Out:
# array([ 1.10296446e+01, -7.74393524e+02,  1.74339246e+04])

# %%
parametros, _ = curve_fit(funcl2, df['porc_eng'], df['limite_credito'])
a, b, c = parametros[ 0 ], parametros[ 1 ], parametros[ 2 ]
yfitl2 = a*x**2 + b*x + c

# %%
yfitl2
# Out:
#        limite_credito
# 0        2.718866e+08
# 1        3.924383e+08
# 2        1.743392e+04
# 3        5.350493e+08
# 4        5.350493e+08
# ...               ...
# 22730    1.095238e+09
# 22731    2.718866e+08
# 22732    2.451954e+08
# 22733    5.350493e+08
# 22734    2.451954e+08
#
# [22735 rows x 1 columns]

# %%
plt.plot(xl2, yl2, 'bo', label="y-original")
plt.plot(xl2, yfitl2, label="a*x**2 + b*x + c")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
R2l2 = r2_score(yl2, yfitl2)
R2l2
# Out:
# -61577984214.904144

# %%
corrl2= np.sqrt(abs(R2l2))
corrl2
# Out:
# 248149.11689325864

# %% [markdown]
# ##Modelo 3: "limite_credito"

# %%
Vars_Indepl3= df[['riesgo']]
Var_Depl3= df['limite_credito']

# %%
xl3= Vars_Indepl3
yl3= Var_Depl3

# %%
def  funcl3 (x, a, b, c):
     return 1/a*x

# %%
parametros, covs= curve_fit(funcl3, df['riesgo'], df['limite_credito'])
# Out:
# /usr/local/lib/python3.10/dist-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
parametros
# Out:
# array([0.08849597, 1.        , 1.        ])

# %%
parametros, _ = curve_fit(funcl3, df['riesgo'], df['limite_credito'])
a, b, c = parametros[ 0 ], parametros[ 1 ], parametros[ 2 ]
yfitl3 = 1/a*x

# %%
yfitl3
# Out:
#        limite_credito
# 0        56499.748966
# 1        67799.698759
# 2            0.000000
# 3        79099.648552
# 4        79099.648552
# ...               ...
# 22730   112999.497932
# 22731    56499.748966
# 22732    53674.761518
# 22733    79099.648552
# 22734    53674.761518
#
# [22735 rows x 1 columns]

# %%
plt.plot(xl3, yl3, 'bo', label="y-original")
plt.plot(xl3, yfitl3, label="1/a*x")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
R2l3 = r2_score(yl3, yfitl3)
R2l3
# Out:
# -922.7174546519271

# %%
corrl3= np.sqrt(abs(R2l3))
corrl3
# Out:
# 30.376264659301466

# %% [markdown]
# ## Modelo 4: "limite_credito"

# %%
Vars_Indepl4= df[['puntos']]
Var_Depl4= df['porc_eng']

# %%
xl4= Vars_Indepl4
yl4= Var_Depl4

# %%
def  funcl4 (x, a, b, c):
     return a*x + b*x + c*x

# %%
parametros, covs= curve_fit(funcl4, df['puntos'], df['porc_eng'])

# %%
parametros
# Out:
# array([-141.12559387,   71.00644048,   71.00644048])

# %%
parametros, _ = curve_fit(funcl4, df['puntos'], df['porc_eng'])
a, b, c = parametros[ 0 ], parametros[ 1 ], parametros[ 2 ]
yfitl4 = a*x + b*x + c*x

# %%
yfitl4
# Out:
#        limite_credito
# 0         4436.435460
# 1         5323.722553
# 2            0.000000
# 3         6211.009645
# 4         6211.009645
# ...               ...
# 22730     8872.870921
# 22731     4436.435460
# 22732     4214.613687
# 22733     6211.009645
# 22734     4214.613687
#
# [22735 rows x 1 columns]

# %%
plt.plot(xl4, yl4, 'bo', label="y-original")
plt.plot(xl4, yfitl4, label="a*x + b*x + c*x")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
R2l4 = r2_score(yl4, yfitl4)
R2l4
# Out:
# -835510.4593914332

# %%
corrl4= np.sqrt(abs(R2l4))
corrl4
# Out:
# 914.0626124021445

# %% [markdown]
# ## Modelo 5: "limite_credito"

# %%
Vars_Indepl5= df[['enganche']]
Var_Depl5= df['limite_credito']

# %%
xl5= Vars_Indepl5
yl5= Var_Depl5

# %%
def  funcl5 (x, a, b, c):
     return a/b*x**2 + c*x

# %%
parametros, covs= curve_fit(funcl5, df['enganche'], df['limite_credito'])

# %%
parametros
# Out:
# array([-6.31235769e-03,  1.15152486e+00,  1.19954654e+01])

# %%
parametros, _ = curve_fit(funcl5, df['enganche'], df['limite_credito'])
a, b, c = parametros[ 0 ], parametros[ 1 ], parametros[ 2 ]
yfitl5 = a/b*x**2 + c*x

# %%
yfitl5
# Out:
#        limite_credito
# 0       -77066.125630
# 1      -125369.779421
# 2            0.000000
# 3      -184636.909434
# 4      -184636.909434
# ...               ...
# 22730  -428219.156804
# 22731   -77066.125630
# 22732   -66703.255342
# 22733  -184636.909434
# 22734   -66703.255342
#
# [22735 rows x 1 columns]

# %%
plt.plot(xl5, yl5, 'bo', label="y-original")
plt.plot(xl5, yfitl5, label="a/b*x**2 + c*x")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
R2l5 = r2_score(yl5, yfitl5)
R2l5
# Out:
# -8775.07653889274

# %%
corrl5= np.sqrt(abs(R2l5))
corrl5
# Out:
# 93.67537850947141

# %% [markdown]
# ##Modelo 1: "porc_eng"

# %%
# @title
Vars_Indepp1= df[['enganche']]
Var_Depp1= df['porc_eng']

# %%
# @title
xp1= Vars_Indepp1
yp1= Var_Depp1

# %%
# @title
def  funcp1 (x, a, b, c):
     return (a*x**10 + b)/ c*x

# %%
# @title
parametros, covs= curve_fit(funcp1, df['enganche'], df['porc_eng'])

# %%
# @title
parametros
# Out:
# array([-5.42538567e-24,  3.82346869e+10,  1.60267973e+12])

# %%
# @title
parametros, _ = curve_fit(funcp1, df['enganche'], df['porc_eng'])
a, b, c = parametros[ 0 ], parametros[ 1 ], parametros[ 2 ]
yfitp1 = (a*x**10 + b)/ c*x

# %%
# @title
yfitp1
# Out:
#        limite_credito
# 0       -1.651735e+05
# 1       -1.227996e+06
# 2        0.000000e+00
# 3       -6.693472e+06
# 4       -6.693472e+06
# ...               ...
# 22730   -3.385194e+08
# 22731   -1.651735e+05
# 22732   -9.390524e+04
# 22733   -6.693472e+06
# 22734   -9.390524e+04
#
# [22735 rows x 1 columns]

# %%
# @title
plt.plot(xp1, yp1, 'bo', label="y-original")
plt.plot(xp1, yfitp1, label="(a*x**2 + b)/ c*x")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
# @title
R2p1 = r2_score(yp1, yfitp1)
R2p1
# Out:
# -839042511675235.0

# %%
# @title
corrp1= np.sqrt(abs(R2p1))
corrp1
# Out:
# 28966230.539634164

# %% [markdown]
# ## Modelo 2: "porc_eng"

# %%
Vars_Indepp2= df[['puntos']]
Var_Depp2= df['porc_eng']

# %%
xp2= Vars_Indepp2
yp2= Var_Depp2

# %%
def  funcp2 (x, a, b, c):
     return a*x**2 + b*x + c

# %%
parametros, covs= curve_fit(funcp2, df['puntos'], df['porc_eng'])

# %%
parametros
# Out:
# array([-3.08769969e-04, -2.16837598e-01,  2.59798609e+01])

# %%
parametros, _ = curve_fit(funcp2, df['puntos'], df['porc_eng'])
a, b, c = parametros[ 0 ], parametros[ 1 ], parametros[ 2 ]
yfitp2 = a*x**2 + b*x + c

# %%
yfitp2
# Out:
#        limite_credito
# 0        -8777.457356
# 1       -12390.764614
# 2           25.979861
# 3       -16621.611811
# 4       -16621.611811
# ...               ...
# 22730   -33019.393029
# 22731    -8777.457356
# 22732    -7970.621157
# 22733   -16621.611811
# 22734    -7970.621157
#
# [22735 rows x 1 columns]

# %%
plt.plot(xp2, yp2, 'bo', label="y-original")
plt.plot(xp2, yfitp2, label="a*x**2 + b*x + c")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
R2p2 = r2_score(yp2, yfitp2)
R2p2
# Out:
# -7133423.523580258

# %%
corrp2= np.sqrt(abs(R2p2))
corrp2
# Out:
# 2670.8469674581243

# %% [markdown]
# ##Modelo 3: "porc_eng"

# %%
Vars_Indepp3= df[['riesgo']]
Var_Depp3= df['porc_eng']

# %%
xp3= Vars_Indepp3
yp3= Var_Depp3

# %%
def  funcp3 (x, a, b, c):
     return 1/a*x

# %%
parametros, covs= curve_fit(funcp3, df['riesgo'], df['porc_eng'])
# Out:
# /usr/local/lib/python3.10/dist-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
parametros
# Out:
# array([1.86830119, 1.        , 1.        ])

# %%
parametros, _ = curve_fit(funcs3, df['riesgo'], df['porc_eng'])
a, b, c = parametros[ 0 ], parametros[ 1 ], parametros[ 2 ]
yfitp3 = 1/a*x

# %%
yfitp3
# Out:
#        limite_credito
# 0         2676.228025
# 1         3211.473630
# 2            0.000000
# 3         3746.719235
# 4         3746.719235
# ...               ...
# 22730     5352.456050
# 22731     2676.228025
# 22732     2542.416624
# 22733     3746.719235
# 22734     2542.416624
#
# [22735 rows x 1 columns]

# %%
plt.plot(xp3, yp3, 'bo', label="y-original")
plt.plot(xp3, yfitp3, label="1/a*x")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
R2p3 = r2_score(yp3, yfitp3)
R2p3
# Out:
# -302598.09377090033

# %%
corrp3= np.sqrt(abs(R2p3))
corrp3
# Out:
# 550.0891689270934

# %% [markdown]
# ## Modelo 4: "porc_eng"

# %%
Vars_Indepp4= df[['limite_credito']]
Var_Depp4= df['porc_eng']

# %%
xp4= Vars_Indepp4
yp4= Var_Depp4

# %%
def  funcp4 (x, a, b, c):
     return a*x + b*x + c*x

# %%
parametros, covs= curve_fit(funcp4, df['limite_credito'], df['porc_eng'])

# %%
parametros
# Out:
# array([-141.44183065,   70.71645255,   70.72857228])

# %%
parametros, _ = curve_fit(funcr4, df['limite_credito'], df['porc_eng'])
a, b, c = parametros[ 0 ], parametros[ 1 ], parametros[ 2 ]
yfitp4 = a*x + b*x + c*x

# %%
yfitp4
# Out:
#        limite_credito
# 0           15.970855
# 1           19.165026
# 2            0.000000
# 3           22.359197
# 4           22.359197
# ...               ...
# 22730       31.941710
# 22731       15.970855
# 22732       15.172312
# 22733       22.359197
# 22734       15.172312
#
# [22735 rows x 1 columns]

# %%
plt.plot(xp4, yp4, 'bo', label="y-original")
plt.plot(xp4, yfitp4, label="a*x + b*x + c*x")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
R2p4 = r2_score(yp4, yfitp4)
R2p4
# Out:
# -3.153925872048835

# %%
corrp4= np.sqrt(abs(R2p4))
corrp4
# Out:
# 1.7759295796987096

# %% [markdown]
# ## Modelo 5: "porc_eng"

# %%
Vars_Indepp5= df[['costo_total']]
Var_Depp5= df['porc_eng']

# %%
xp5= Vars_Indepp5
yp5= Var_Depp5

# %%
def  funcp5 (x, a, b, c):
     return a/b*x**2 + c*x

# %%
parametros, covs= curve_fit(funcp5, df['costo_total'], df['porc_eng'])

# %%
parametros
# Out:
# array([-4.42715079e-06,  7.46152589e+00,  7.76309420e-03])

# %%
parametros, _ = curve_fit(funcp5, df['costo_total'], df['porc_eng'])
a, b, c = parametros[ 0 ], parametros[ 1 ], parametros[ 2 ]
yfitp5 = a/b*x**2 + c*x

# %%
yfitp5
# Out:
#        limite_credito
# 0           23.982209
# 1           25.218668
# 2            0.000000
# 3           25.268466
# 4           25.268466
# ...               ...
# 22730       18.297893
# 22731       23.982209
# 22732       23.487678
# 22733       25.268466
# 22734       23.487678
#
# [22735 rows x 1 columns]

# %%
plt.plot(xp5, yp5, 'bo', label="y-original")
plt.plot(xp5, yfitp5, label="a/b*x**2 + c*x")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
R2p5 = r2_score(yp5, yfitp5)
R2p5
# Out:
# -0.30274040715798556

# %%
corrp5= np.sqrt(abs(R2p5))
corrp5
# Out:
# 0.5502185085563603
